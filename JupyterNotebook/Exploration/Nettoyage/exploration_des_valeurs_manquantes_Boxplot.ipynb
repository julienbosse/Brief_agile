# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("donnees/housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data_columns = data.columns
data_columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
nbdeNAN_total_bedrooms = data[data_columns][data[data_columns[4]].isna()==True].shape[0]
nbdeNAN_total_bedrooms
# Out:
# 207

# %%
plt.figure(figsize=[9,6])
sns.set_context("notebook",rc={'xtick.labelsize':18,'ytick.labelsize':13})
palette=sns.color_palette("YlOrBr")
sns.set_palette(palette)
plt.subplot(111)

sns.boxplot(data=donnees_boxplot,dodge=True)
plt.xticks(rotation=90)
plt.show()
plt.close()

# %%
plt.figure(figsize=[9,6])
sns.set_context("notebook",rc={'xtick.labelsize':18,'ytick.labelsize':13})
palette=sns.color_palette("YlOrBr")
sns.set_palette(palette)
plt.subplot(111)

sns.boxplot(data=data[['total_rooms']],dodge=True)
plt.xticks(rotation=90)
plt.show()
plt.close()

# %%
plt.figure(figsize=[9,6])
sns.set_context("notebook",rc={'xtick.labelsize':18,'ytick.labelsize':13})
palette=sns.color_palette("YlOrBr")
sns.set_palette(palette)
plt.subplot(111)

sns.boxplot(data=data[['population']],dodge=True)
plt.xticks(rotation=90)
plt.show()
plt.close()

# %%
plt.figure(figsize=[9,6])
sns.set_context("notebook",rc={'xtick.labelsize':18,'ytick.labelsize':13})
palette=sns.color_palette("YlOrBr")
sns.set_palette(palette)
plt.subplot(111)

sns.boxplot(data=data[['households']],dodge=True)
plt.xticks(rotation=90)
plt.show()
plt.close()

# %%
plt.figure(figsize=[9,6])
sns.set_context("notebook",rc={'xtick.labelsize':18,'ytick.labelsize':13})
palette=sns.color_palette("YlOrBr")
sns.set_palette(palette)
plt.subplot(111)

sns.boxplot(data=data[['median_income']],dodge=True)
plt.xticks(rotation=90)
plt.show()
plt.close()

# %%
correlation = donnees_boxplot.corr()
plt.figure()
plt.subplot(111)
sns.heatmap(correlation,annot=True,linewidths=1.0)
plt.show()
plt.close()

# %%
data[data_columns][data[data_columns[4]].isna()==True]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                47.0       1256.0             NaN
# 341      -122.17     37.75                38.0        992.0             NaN
# 538      -122.28     37.78                29.0       5154.0             NaN
# 563      -122.24     37.75                45.0        891.0             NaN
# 696      -122.10     37.69                41.0        746.0             NaN
# ...          ...       ...                 ...          ...             ...
# 20267    -119.19     34.20                18.0       3620.0             NaN
# 20268    -119.18     34.19                19.0       2393.0             NaN
# 20372    -118.88     34.17                15.0       4260.0             NaN
# 20460    -118.75     34.29                17.0       5512.0             NaN
# 20484    -118.72     34.28                17.0       3051.0             NaN
#
# ...

# %%
data[data_columns[4]][data[data_columns[4]].isna()==True] = np.mean(data[data_columns[4]][data[data_columns[4]].isna()==False])
# Out:
# <ipython-input-8-63031e720e24>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[data_columns[4]][data[data_columns[4]].isna()==True] = np.mean(data[data_columns[4]][data[data_columns[4]].isna()==False])

# %%
data = data.drop(data[data["population"]>20000].index.tolist())

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.to_csv("donnees/housing_clean.csv")
